# %%
import pandas as pd

# %%
pd.read_csv('ipo_reservation_df.csv')
# Out:
#                                     company_name     qib_shares_offered  \
# 0          Mangal Electrical Industries Ltd. IPO     35,65,062 (50.00%)
# 1                          Patel Retail Ltd. IPO     28,40,700 (29.84%)
# 2                         Gem Aromatics Ltd. IPO     69,42,306 (50.00%)
# 3                          Vikram Solar Ltd. IPO   3,11,65,200 (49.76%)
# 4               Shreeji Shipping Global Ltd. IPO     81,49,000 (50.00%)
# 5                      Regaal Resources Ltd. IPO   1,49,99,760 (50.00%)
# 6       BlueStone Jewellery & Lifestyle Ltd. IPO   2,23,49,850 (75.00%)
# 7                     All Time Plastics Ltd. IPO     72,67,504 (49.88%)
# 8                            JSW Cement Ltd. IPO  12,24,48,978 (50.00%)
# 9                Highway Infrastructure Ltd. IPO     55,71,427 (30.00%)
# 10        Sri Lotus Developers & Realty Ltd. IPO   2,63,33,332 (49.86%)
# 11                      M&B Engineering Ltd. IPO   1,26,23,377 (74.75%)
# ...
